# %%
import sqlalchemy

# %%
sqlalchemy.create_engine('postgresql://postgres:JustForPostGres@localhost/FirstDB')
# Out:
# Engine(postgresql://postgres:***@localhost/FirstDB)

# %%
# %load_ext sql

# %%
# Example format
# %sql postgresql://postgres:JustForPostGres@localhost/FirstDB

# %%
# assign a variable that contains a string of your credentials
credentials = "postgresql://postgres:JustForPostGres@localhost/FirstDB"

# %%
# %%sql
# select * from checkout
# Out:
#  * postgresql://postgres:***@localhost/FirstDB
# 5 rows affected.
# [('Jignesh', 'Potato, Carrots, Turnips'),
#  ('Susan', 'Sugar, Butter, Eggs, flour'),
#  ('Sari', 'Hacksaw, Rope, Gravel'),
#  ('Masaba', 'Eyeliner, Lotion, Turmeric paste'),
#  ('Chris', 'Candles, Card')]

# %%
import pandas as pd
dataframe = pd.read_sql("""
            select * from checkout
            """, con = credentials)

# %%
dataframe
# Out:
#   customer                            orders
# 0  Jignesh          Potato, Carrots, Turnips
# 1    Susan        Sugar, Butter, Eggs, flour
# 2     Sari             Hacksaw, Rope, Gravel
# 3   Masaba  Eyeliner, Lotion, Turmeric paste
# 4    Chris                     Candles, Card
